# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import pickle
import sys
from pathlib import Path

# Add the src directory to the path
sys.path.insert(0, '/Users/yew/code/neon-agbd/')


from neon_agbd.vst.main import compute_site_biomass_full, ALL_SITES

# %%
def process_site(site_id: str, output_dir: str = "./output") -> dict:
    """
    Process a single NEON site and save results.

    Parameters
    ----------
    site_id : str
        Four-character NEON site code (e.g., 'SJER', 'HARV')
    output_dir : str
        Directory to save output files

    Returns
    -------
    dict
        Dictionary containing all output tables and metadata
    """
    # Ensure output directory exists
    Path(output_dir).mkdir(exist_ok=True)

    csvs_output_dir = Path(output_dir) / "csvs"
    csvs_output_dir.mkdir(parents=True, exist_ok=True)

    print(f"\n{'='*60}")
    print(f"Processing site: {site_id}")
    print(f"{'='*60}\n")

    # Run the full workflow
    output = compute_site_biomass_full(
        site_id=site_id,
        dp1_data_dir="../data/DP1.10098",
        agb_data_dir="../data/NEONForestAGB",
        plot_polygons_path="../data/plot_polygons/NEON_TOS_Plot_Polygons.geojson",
        apply_gap_filling=True,
        apply_dead_corrections=True,
        verbose=True
    )

    # Save as pickle (dictionary)
    pkl_file = Path(output_dir) / f"{site_id}.pkl"
    with open(pkl_file, 'wb') as f:
        pickle.dump(output, f)
    print(f"\nPickle file saved: {pkl_file}")

    # Save individual DataFrames as CSVs for easy inspection
    csv_files = {
        'plot_biomass': f"{site_id}_plot_biomass.csv",
        'unaccounted_trees': f"{site_id}_unaccounted_trees.csv",
        'individual_trees': f"{site_id}_individual_trees.csv"
    }

    for key, filename in csv_files.items():
        filepath = Path(csvs_output_dir) / filename
        output[key].to_csv(filepath, index=False)
        print(f"CSV saved: {filepath}")

    # Print summary
    print(f"\n{'='*60}")
    print("Summary:")
    print(f"{'='*60}")
    print(f"  Site: {output['site_id']}")
    print(f"  Number of plots: {output['metadata']['n_plots']}")
    print(f"  Plot-year combinations: {output['metadata']['n_plot_years']}")
    print(f"  Unaccounted trees: {output['metadata']['n_unaccounted_trees']}")
    print(f"  Individual tree records: {output['metadata']['n_individual_tree_records']}")

    # Show sample of each output
    if not output['plot_biomass'].empty:
        print(f"\nPlot biomass table columns:")
        print(f"  {list(output['plot_biomass'].columns)}")
        print(f"\nSample rows:")
        print(output['plot_biomass'].head(3).to_string())

    if not output['unaccounted_trees'].empty:
        print(f"\nUnaccounted trees by status:")
        print(output['unaccounted_trees']['status'].value_counts().to_string())

    return output

# %%
dpids= ['DELA','LENO','TALL','BONA','DEJU','HEAL','SRER','SJER','SOAP',
              'TEAK','CPER','NIWO','RMNP','DSNY','OSBS','JERC','PUUM','KONZ',
              'UKFS','SERC','HARV','UNDE','BART','JORN','DCFS','NOGP','WOOD',
              'GUAN','LAJA','GRSM','ORNL','CLBJ','MOAB','ONAQ','BLAN','MLBS',
              'SCBI','ABBY','WREF','STEI','TREE','YELL']

for site_id in dpids:
	process_site(site_id, output_dir="./results/")

# %%
process_site(site_id = 'ABBY', output_dir="./results/vst/")
# Out:
# ============================================================
# Processing site: ABBY
# ============================================================
#
# Processing site: ABBY
#   Loading DP1.10098 data...
#   Loading NEONForestAGB data...
#   Merging AGB estimates with apparent individual data...
#   Loading plot area data...
#   Found 130 plot-year combinations from vst_perplotperyear
#   Categorizing individuals (tree vs small_woody)...
#   Applying dead status corrections...
#   Identifying unaccounted trees...
#   Computing plot-level biomass...
#   Calculating growth metrics...
#   Creating individual tree table...
#   Done! Computed biomass for 130 plot-year combinations.
#   Found 411 unaccounted trees.
#   Created individual tree table with 4258 records.
#
# Pickle file saved: results/vst/ABBY.pkl
# CSV saved: results/vst/csvs/ABBY_plot_biomass.csv
# CSV saved: results/vst/csvs/ABBY_unaccounted_trees.csv
# CSV saved: results/vst/csvs/ABBY_individual_trees.csv
#
# ============================================================
# Summary:
# ============================================================
#   Site: ABBY
#   Number of plots: 34
#   Plot-year combinations: 130
#   Unaccounted trees: 411
#   Individual tree records: 4258
#
# Plot biomass table columns:
#   ['siteID', 'plotID', 'year', 'plotArea_m2', 'tree_AGBJenkins', 'tree_AGBChojnacky', 'tree_AGBAnnighofer', 'n_trees', 'small_woody_AGBJenkins', 'small_woody_AGBChojnacky', 'small_woody_AGBAnnighofer', 'n_small_woody_total', 'n_small_woody_measured', 'n_unaccounted_trees', 'total_AGBJenkins', 'total_AGBChojnacky', 'total_AGBAnnighofer', 'growth', 'growth_cumu']
#
# Sample rows:
#   siteID    plotID  year  plotArea_m2  tree_AGBJenkins  tree_AGBChojnacky  tree_AGBAnnighofer  n_trees  small_woody_AGBJenkins  small_woody_AGBChojnacky  small_woody_AGBAnnighofer  n_small_woody_total  n_small_woody_measured  n_unaccounted_trees  total_AGBJenkins  total_AGBChojnacky  total_AGBAnnighofer    growth  growth_cumu
# 0   ABBY  ABBY_001  2016       1600.0       115.219626         110.427987                 NaN       11                0.489534                  0.438844                   0.420809                   41                      18                    2        115.709160          110.866831             0.420809       NaN     1.159682
# 1   ABBY  ABBY_001  2019       1600.0       118.515381         112.831040                 NaN        9                0.672824                  0.604206                   0.393183                   41                      19                    2        119.188205          113.435247             0.393183  1.159682     1.159682
# 2   ABBY  ABBY_002  2016       1600.0         0.000000           0.000000                 0.0        0                0.279506                  0.200257                   0.656258                   56                      50                   21          0.279506            0.200257             0.656258       NaN     0.472998
#
# Unaccounted trees by status:
# status
# UNMEASURED      410
# NO_ALLOMETRY      1
# {'categoricalCodes_10098':                            name         pubCode  \
#  0     Identification Qualifiers     cf. species
#  1     Identification Qualifiers    aff. species
#  2     Identification Qualifiers       cf. genus
#  3     Identification Qualifiers      aff. genus
#  4     Identification Qualifiers  cf. subspecies
#  ..                          ...             ...
#  305            Yes or No choice               Y
#  306            Yes or No choice               N
#  307  Yes, No, or Unknown choice               Y
#  308  Yes, No, or Unknown choice               N
#  309  Yes, No, or Unknown choice               U
#
#                                             description             startDate  \
#  0      roughly equals but 'not sure' about the species  2012-01-01T00:00:00Z
#  1                    similar to but is not the species  2012-01-01T00:00:00Z
#  2        roughly equals but 'not sure' about the genus  2012-01-01T00:00:00Z
#  3                      similar to but is not the genus  2012-01-01T00:00:00Z
#  4    roughly equals but 'not sure' about the subspe...  2012-01-01T00:00:00Z
#  ..                                                 ...                   ...
#  305                                                Yes  2012-01-01T00:00:00Z
#  306                                                 No  2012-01-01T00:00:00Z
#  307                                                Yes  2012-01-01T00:00:00Z
#  308                                                 No  2012-01-01T00:00:00Z
#  309                                            Unknown  2012-01-01T00:00:00Z
#
#      endDate
#  0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#  ..      ...
#  305     NaN
#  306     NaN
#  307     NaN
#  308     NaN
#  309     NaN
#
#  [310 rows x 5 columns],
#  'citation_10098_RELEASE-2025': '@misc{https://doi.org/10.48443/653k-mf13,\n  doi = {10.48443/653K-MF13},\n  url = {https://data.neonscience.org/data-products/DP1.10098.001/RELEASE-2025},\n  author = {{National Ecological Observatory Network (NEON)}},\n  keywords = {plant productivity, production, carbon cycle, biomass, vegetation, productivity, plants, trees, shrubs, lianas, saplings, net primary productivity (NPP), annual net primary productivity (ANPP), woody plants, vegetation structure, tree height, canopy height, vst, biodiversity},\n  language = {en},\n  title = {Vegetation structure (DP1.10098.001)},\n  publisher = {National Ecological Observatory Network (NEON)},\n  year = {2025}\n}\n',
#  'issueLog_10098':        id parentIssueID             issueDate          resolvedDate  \
#  0   16302          None  2020-10-01T00:00:00Z  2020-10-01T00:00:00Z
#  1   16303          None  2020-10-01T00:00:00Z  2020-10-01T00:00:00Z
#  2   16304          None  2020-10-01T00:00:00Z  2020-10-01T00:00:00Z
#  3   16305          None  2020-10-01T00:00:00Z  2020-07-31T00:00:00Z
#  4   16306          None  2020-03-10T00:00:00Z  2020-03-10T00:00:00Z
#  5   16307          None  2019-03-05T00:00:00Z  2020-07-31T00:00:00Z
#  6   17962          None  2021-01-06T00:00:00Z  2021-12-31T00:00:00Z
#  7   19395          None  2021-03-24T00:00:00Z  2021-01-01T00:00:00Z
#  8   37604          None  2019-03-05T00:00:00Z  2020-07-31T00:00:00Z
#  9   37605          None  2020-03-05T00:00:00Z  2020-03-05T00:00:00Z
#  10  37606          None  2021-11-24T00:00:00Z  2022-01-01T00:00:00Z
#  11  37607          None  2021-12-03T00:00:00Z  2021-12-10T00:00:00Z
#  12  38407          None  2021-12-09T00:00:00Z  2021-12-31T00:00:00Z
#  13  38604          None  2021-12-06T00:00:00Z  2021-12-06T00:00:00Z
#  14  52904          None  2022-02-02T00:00:00Z  2023-01-01T00:00:00Z
#  15  52905          None  2022-02-23T00:00:00Z  2022-02-23T00:00:00Z
#  16  68808          None  2022-09-15T00:00:00Z  2022-10-31T00:00:00Z
#  17  76304          None  2022-10-25T00:00:00Z  2023-01-01T00:00:00Z
#  18  77904          None  2023-03-01T00:00:00Z  2023-03-01T00:00:00Z
#  19  77905          None  2023-03-01T00:00:00Z  2023-03-01T00:00:00Z
#  20  77906          None  2023-03-01T00:00:00Z  2023-03-01T00:00:00Z
#  21  77907          None  2023-03-01T00:00:00Z  2023-03-01T00:00:00Z
#  22  77908          None  2023-03-01T00:00:00Z                  None
#  23  78405          None  2023-04-12T00:00:00Z  2023-04-01T00:00:00Z
#  24  78804          None  2023-05-09T00:00:00Z  2023-12-31T00:00:00Z
#  25  81910          None  2023-11-09T00:00:00Z  2023-12-31T00:00:00Z
#  26  83404          None  2023-12-12T00:00:00Z  2023-12-06T00:00:00Z
#  27  84605          None  2023-12-22T00:00:00Z  2024-01-01T00:00:00Z
#  28  86204          None  2024-02-07T00:00:00Z  2023-11-08T00:00:00Z
#  29  92604          None  2024-09-05T00:00:00Z  2024-08-27T00:00:00Z
#  30  95204          None  2024-11-08T00:00:00Z  2024-12-31T00:00:00Z
#  31  95504          None  2024-11-12T00:00:00Z                  None
#  32  98704          None  2025-01-15T00:00:00Z  2024-08-01T00:00:00Z
#  33  99904          None  2025-02-17T00:00:00Z  2025-02-17T00:00:00Z
#  34  99905          None  2025-02-17T00:00:00Z  2025-12-31T00:00:00Z
#
#            dateRangeStart          dateRangeEnd  \
#  0   2014-01-01T00:00:00Z  2017-03-09T00:00:00Z
#  1   2014-01-01T00:00:00Z  2017-03-09T00:00:00Z
#  2   2017-03-09T00:00:00Z  2019-08-30T00:00:00Z
#  3   2017-01-01T00:00:00Z  2020-07-31T00:00:00Z
#  4   2014-01-01T00:00:00Z  2020-03-10T00:00:00Z
#  5   2014-01-01T00:00:00Z  2020-07-31T00:00:00Z
#  6   2020-03-23T00:00:00Z  2021-12-31T00:00:00Z
#  7   2013-01-01T00:00:00Z  2021-01-01T00:00:00Z
#  8   2014-01-01T00:00:00Z  2020-07-31T00:00:00Z
#  9   2014-01-01T00:00:00Z  2020-03-05T00:00:00Z
#  10  2018-01-01T00:00:00Z  2021-12-31T00:00:00Z
#  11  2014-01-01T00:00:00Z  2021-12-10T00:00:00Z
#  12  2012-01-01T00:00:00Z  2021-12-31T00:00:00Z
#  13  2014-01-01T00:00:00Z  2020-01-01T00:00:00Z
#  14  2014-01-01T00:00:00Z  2021-01-01T00:00:00Z
#  15  2020-01-01T00:00:00Z  2021-12-31T00:00:00Z
#  16  2022-06-12T00:00:00Z  2022-10-31T00:00:00Z
#  17  2016-01-01T00:00:00Z  2022-01-01T00:00:00Z
#  18  2015-01-01T00:00:00Z  2023-03-01T00:00:00Z
#  19  2015-01-01T00:00:00Z  2023-03-01T00:00:00Z
#  20  2018-01-01T00:00:00Z  2023-03-01T00:00:00Z
#  21  2015-01-01T00:00:00Z  2023-03-01T00:00:00Z
#  22  2015-01-01T00:00:00Z  2023-03-31T00:00:00Z
#  23  2016-07-01T00:00:00Z  2023-04-01T00:00:00Z
#  24  2012-01-01T00:00:00Z  2023-04-25T00:00:00Z
#  25  2023-01-01T00:00:00Z  2023-12-31T00:00:00Z
#  26  2023-09-19T00:00:00Z  2023-11-03T00:00:00Z
#  27  2012-01-01T00:00:00Z  2023-01-01T00:00:00Z
#  28  2020-03-01T00:00:00Z  2023-08-01T00:00:00Z
#  29  2014-01-01T00:00:00Z  2024-08-14T00:00:00Z
#  30  2015-01-01T00:00:00Z  2016-01-01T00:00:00Z
#  31  2014-01-01T00:00:00Z  2024-07-01T00:00:00Z
#  32  2015-07-01T00:00:00Z  2023-12-01T00:00:00Z
#  33  2015-07-01T00:00:00Z  2024-11-21T00:00:00Z
#  34  2019-07-15T00:00:00Z  2024-11-21T00:00:00Z
#
#                                       locationAffected  \
#  0                              MOAB, JORN, SRER, ONAQ
#  1   RMNP, YELL, NIWO, MOAB, SRER, JORN, ONAQ, WREF...
#  2   RMNP, YELL, NIWO, MOAB, SRER, JORN, ONAQ, WREF...
#  3   All sites for which woody vegetation structure...
#  4   All sites for which woody vegetation structure...
#  5   All sites for which woody vegetation structure...
#  6                                                 All
#  7                                                 All
#  8   All sites for which non-herbaceous perennial v...
#  9   ABBY, BART, DELA, GRSM, HARV, LENO, MLBS, SCBI...
#  10                                               TEAK
#  11  All sites for which non-herbaceous perennial v...
#  12                                                All
#  13  HARV, WOOD, CLBJ, GRSM, ORNL, OSBS, HEAL, GUAN...
#  14  ABBY, BART, BLAN, BONA, CLBJ, DEJU, DELA, GRSM...
#  15                                   STEI, TREE, UNDE
#  16                                               YELL
#  17               all sites with qualifying vegetation
#  18  All sites at which the ‘fern’ growth form is s...
#  19                                   DSNY, JERC, OSBS
#  20                                               PUUM
#  21                                                All
#  22                                   DSNY, JERC, OSBS
#  23                                       D08-LENO_069
#  24                                                D01
#  25                              All terrestrial sites
#  26                                               MOAB
#  27                                                All
#  28  STEI, TREE, UNDE, KONZ, GRSM, MLBS, ORNL, DELA...
#  29           JERC, OSBS, GUAN, CPER, CLBJ, JORN, SRER
#  30                                   OSBS, DELA, LENO
#  31     STEI, TREE, UNDE, KONZ, UKFS, SOAP, TEAK, DEJU
#  32                                         ABBY, WREF
#  33                             RMNP, NIWO, ABBY, WREF
#  34                                         ABBY, WREF
#
#                                                  issue  \
#  0   Reduced temporal sampling: Annual sampling of ...
#  1   Reduced temporal sampling: Low quality annual ...
#  2   New dendrometer band method:  Lack of annual s...
#  3   Missing perboutperyear values: In the vst_perb...
#  4   No sampling impractical: Before 2020, distribu...
#  5   Multi-stem duplicates: Prior to the resolution...
#  6   Safety measures to protect personnel during th...
#  7   Missing canopy position/crown diameter: Many w...
#  8   Non-herbaceous duplicates: Prior to the resolu...
#  9   Reduced temporal fern sampling: Sampling effor...
#  10  Non-standard sampling date: At the Domain 17 T...
#  11  Data products not bundled: Prior to Dec 2021, ...
#  12  State-level taxa obfuscation: Prior to the 202...
#  13  Missing metadata values: Plot metadata records...
#  14  Non-woody data missing: `vst_perplotperyear` s...
#  15  Incorrect plots were sampled for the annual To...
#  16  Severe flooding destroyed several roads into Y...
#  17  Discontinuing Absence List: The 'Absence List'...
#  18  Spatial scaling issue for ferns and ‘other’ gr...
#  19  A single ‘palm’ growth form was applied to all...
#  20  A single ‘tree fern’ growth form was applied t...
#  21  Available nested subplots in 40m x 40m Tower p...
#  22  Increased spatial data uncertainty: In Domain ...
#  23  Subplot changed from 23 to subplot 39 at LENO_...
#  24  D01 state-level taxa obfuscation: Prior to the...
#  25  SubplotId change: The Base plot subplot naming...
#  26  Incorrect assessment criteria used at MOAB: Th...
#  27  Identification history: updates to taxonomic d...
#  28  Plot Prioritization deviation for annually sam...
#  29  Yucca sampling: The protocol lacked a height t...
#  30  Legacy data collection: During the 2015 field ...
#  31  Duplicate tagIDs across plots: Quality checks ...
#  32  Break height error: Break height data may have...
#  33  Crown diameter error: For leaning individuals,...
#  34  Missed Xerophyllum sampling: Xerophyllum tenax...
#
#                                             resolution
#  0   Annual sampling of tower plots discontinued at...
#  1   Annual sampling of tower plots discontinued at...
#  2   Installed dendrometer bands to enable high-res...
#  3   Missing data were located, L0 edits were perfo...
#  4   NEON added the ‘samplingImpractical’ quality f...
#  5   The `tempStemID` field was added to the vst_ap...
#  6   The primary impact of the pandemic on observat...
#  7   Updated data entry mobile applications now pre...
#  8   The `individualID` in the vst_non-woody table ...
#  9   The NEON Plant Biomass and Productivity Techni...
#  10  The NEON Plant Biomass and Productivity TWG as...
#  11  The ‘Woody plant vegetation structure’ (DP1.10...
#  12  The state-level obfuscation routine was remove...
#  13  NEON recommends users apply sampling areas fro...
#  14  Missing fields added to the bundled vegetation...
#  15  From 2022 onward, Tower plots selected for ann...
#  16  Normal operations resumed on October 31, 2022,...
#  17  NEON has implemented additional quality contro...
#  18  Introduced new ‘nestedSubplotAreaFerns’ and ‘t...
#  19  The ‘palm’ growth form was deprecated and repl...
#  20  The ‘tree fern’ growth form was deprecated and...
#  21  A 50 meter square nested subplot size was intr...
#  22  Plot markers have been switched to flame-resis...
#  23  Due to persistent flooding, it is no longer po...
#  24  To reduce the number of records in which taxon...
#  25  The subplot naming convention is updated acros...
#  26  Qualification criteria for cover assessment an...
#  27  In provisional data, RELEASE-2024, and all sub...
#  28  For the site-specific resolution dates identif...
#  29  A 30 cm height threshold for sampling yucca wa...
#  30  Records summer 2015 sampling effort at DELA an...
#  31  Domain staff have used old data sheets and fie...
#  32  From 2024 onward, reported break height data c...
#  33  From 2025 onward, reported crown diameter data...
#  34  From 2025 onward, sampling for Xerophyllum ten...  ,
#  'readme_10098':                                                      0
#  0                  ###################################
#  1                  ########### Disclaimer ############
#  2    This is the most recent readme publication bas...
#  3    Information specific to the query, including s...
#  4                   ##################################
#  ..                                                 ...
#  288  NEON data are initially published with a statu...
#  289  algorithms will occur on an as-needed basis, a...
#  290  as part of a Data Release, they are no longer ...
#  291  To learn more about provisional versus release...
#  292  https://www.neonscience.org/data-revisions-rel...
#
#  [293 rows x 1 columns],
#  'validation_10098':                          table                 fieldName  \
#  0               vst_shrubgroup                       uid
#  1               vst_shrubgroup                 startDate
#  2               vst_shrubgroup                   endDate
#  3               vst_shrubgroup                   eventID
#  4               vst_shrubgroup                    plotID
#  ..                         ...                       ...
#  219  vst_identificationHistory  identificationReferences
#  220  vst_identificationHistory     identificationRemarks
#  221  vst_identificationHistory                   remarks
#  222  vst_identificationHistory              identifiedBy
#  223  vst_identificationHistory                    dataQF
#
#                                             description  dataType units  \
#  0    Unique ID within NEON database; an identifier ...    string   NaN
#  1    The start date-time or interval during which a...  dateTime   NaN
#  2    The end date-time or interval during which an ...  dateTime   NaN
#  3    An identifier for the set of information assoc...    string   NaN
#  4                 Plot identifier (NEON site code_XXX)    string   NaN
#  ..                                                 ...       ...   ...
#  219  A list of sources (concatenated and semicolon ...    string   NaN
#  220         Comments or notes about the identification    string   NaN
#  221  Technician notes; free text comments accompany...    string   NaN
#  222  An identifier for the technician who identifie...    string   NaN
#  223                                  Data quality flag    string   NaN
#
#                        parserToCreate  \
#  0                       [CREATE_UID]
#  1    [CONVERT_TO_UTC(namedLocation)]
#  2    [CONVERT_TO_UTC(namedLocation)]
#  3                                NaN
#  4                                NaN
#  ..                               ...
#  219                              NaN
#  220                            [LOV]
#  221                              NaN
#  222                              NaN
#  223                              NaN
#
#                            entryValidationRulesParser  \
#  0                                                NaN
#  1                                          [REQUIRE]
#  2                                          [REQUIRE]
#  3                                   [REQUIRE][ASCII]
#  4    [REQUIRE][NAMED_LOCATION_TYPE('OS Plot - vst')]
#  ..                                               ...
#  219                          [ASCII][REQUIRE_COLUMN]
#  220                                 [REQUIRE_COLUMN]
#  221                          [ASCII][REQUIRE_COLUMN]
#  222                 [REQUIRE][ASCII][REQUIRE_COLUMN]
#  223                                          [ASCII]
#
#                                entryValidationRulesForm
#  0                                                  NaN
#  1    [REQUIRE][SUGGESTED_ENTRY(systemDate)][DATE_FO...
#  2                [REQUIRE][SUGGESTED_ENTRY(startDate)]
#  3    [FROM_TABLE(vst_perplotperyear_in)][SUGGESTED_...
#  4    [REQUIRE][NAMED_LOCATION_TYPE('OS Plot - vst')...
#  ..                                                 ...
#  219                                                NaN
#  220                                                NaN
#  221                                                NaN
#  222                                                NaN
#  223                                                NaN
#
#  [224 rows x 8 columns],
#  'variables_10098':                       table        fieldName  \
#  0    vst_apparentindividual              uid
#  1    vst_apparentindividual    namedLocation
#  2    vst_apparentindividual             date
#  3    vst_apparentindividual          eventID
#  4    vst_apparentindividual         domainID
#  ..                      ...              ...
#  214          vst_shrubgroup       measuredBy
#  215          vst_shrubgroup       recordedBy
#  216          vst_shrubgroup           dataQF
#  217          vst_shrubgroup  publicationDate
#  218          vst_shrubgroup          release
#
#                                             description  dataType units  \
#  0    Unique ID within NEON database; an identifier ...    string   NaN
#  1    Name of the measurement location in the NEON d...    string   NaN
#  2    Date or date and time of measurement, observat...  dateTime   NaN
#  3    An identifier for the set of information assoc...    string   NaN
#  4                 Unique identifier of the NEON domain    string   NaN
#  ..                                                 ...       ...   ...
#  214  An identifier for the technician who measured ...    string   NaN
#  215  An identifier for the technician who recorded ...    string   NaN
#  216                                  Data quality flag    string   NaN
#  217   Date of data publication on the NEON data portal  dateTime   NaN
#  218                        Identifier for data release    string   NaN
#
#                    downloadPkg          pubFormat primaryKey  \
#  0                       basic               asIs          N
#  1                       basic               asIs          N
#  2                       basic  yyyy-MM-dd(floor)          N
#  3                       basic               asIs          Y
#  4                       basic               asIs          N
#  ..                        ...                ...        ...
#  214                     basic               asIs          N
#  215                     basic               asIs          N
#  216                     basic               asIs          N
#  217  appended by stackByTable                NaN          N
#  218  appended by stackByTable                NaN          N
#
#      categoricalCodeName
#  0                   NaN
#  1                   NaN
#  2                   NaN
#  3                   NaN
#  4                   NaN
#  ..                  ...
#  214                 NaN
#  215                 NaN
#  216                 NaN
#  217                 NaN
#  218                 NaN
#
#  [219 rows x 9 columns],
#  'vst_apparentindividual':                                         uid          namedLocation  \
#  0      41d93ab2-1312-4b20-bc85-f8aa3c9b8c35  ABBY_063.basePlot.vst
#  1      224d5fe2-0c7a-4a60-a673-31042f027f94  ABBY_063.basePlot.vst
#  2      8443ac38-4c8a-4ae9-b189-ffe3b3710711  ABBY_063.basePlot.vst
#  3      9c4d0422-fe48-4116-bfa5-9d9b448f2a35  ABBY_063.basePlot.vst
#  4      4a8446e4-dd75-4142-af1d-3405456720ab  ABBY_063.basePlot.vst
#  ...                                     ...                    ...
#  13117  11bb0009-caf1-48fc-a85f-7de6cfbd011e  ABBY_073.basePlot.vst
#  13118  d9506465-3ad5-492c-ab18-9a594dedd8de  ABBY_073.basePlot.vst
#  13119  0d2660bb-3b12-407f-9646-d4c281ec7481  ABBY_073.basePlot.vst
#  13120  1e349c1c-a136-40f8-8c35-f10ee4fa4b42  ABBY_073.basePlot.vst
#  13121  f77f128d-39e5-4d3b-9c96-c415823023d3  ABBY_073.basePlot.vst
#
#               date        eventID domainID siteID    plotID subplotID  \
#  0      2015-07-23  vst_ABBY_2015      D16   ABBY  ABBY_063    39_400
#  1      2015-07-23  vst_ABBY_2015      D16   ABBY  ABBY_063    39_400
#  2      2015-07-23  vst_ABBY_2015      D16   ABBY  ABBY_063    21_400
#  3      2015-07-23  vst_ABBY_2015      D16   ABBY  ABBY_063    39_400
#  4      2015-07-23  vst_ABBY_2015      D16   ABBY  ABBY_063    21_400
#  ...           ...            ...      ...    ...       ...       ...
#  13117  2023-11-02  vst_ABBY_2023      D16   ABBY  ABBY_073    39_400
#  13118  2023-11-02  vst_ABBY_2023      D16   ABBY  ABBY_073    23_400
#  13119  2023-11-02  vst_ABBY_2023      D16   ABBY  ABBY_073    39_400
#  13120  2023-11-02  vst_ABBY_2023      D16   ABBY  ABBY_073    39_400
#  13121  2023-11-02  vst_ABBY_2023      D16   ABBY  ABBY_073    39_400
#
#                    individualID tempStemID  ... dendrometerGap  \
#  0      NEON.PLA.D16.ABBY.00453             ...            NaN
#  1      NEON.PLA.D16.ABBY.00446             ...            NaN
#  2      NEON.PLA.D16.ABBY.00434             ...            NaN
#  3      NEON.PLA.D16.ABBY.00454             ...            NaN
#  4      NEON.PLA.D16.ABBY.00417             ...            NaN
#  ...                        ...        ...  ...            ...
#  13117  NEON.PLA.D16.ABBY.07959          1  ...            NaN
#  13118  NEON.PLA.D16.ABBY.03588          1  ...            NaN
#  13119  NEON.PLA.D16.ABBY.01509          1  ...            NaN
#  13120  NEON.PLA.D16.ABBY.07957          1  ...            NaN
#  13121  NEON.PLA.D16.ABBY.00174          1  ...            NaN
#
#        dendrometerCondition bandStemDiameter  \
#  0                                       NaN
#  1                                       NaN
#  2                                       NaN
#  3                                       NaN
#  4                                       NaN
#  ...                    ...              ...
#  13117                                   NaN
#  13118                                   NaN
#  13119                                   NaN
#  13120                                   NaN
#  13121                                   NaN
#
#                                                   remarks           recordedBy  \
#  0                                                         kzias@field-ops.org
#  1                                                         kzias@field-ops.org
#  2                                                         kzias@field-ops.org
#  3                          no transcription errors found  kzias@field-ops.org
#  4                                                         kzias@field-ops.org
#  ...                                                  ...                  ...
#  13117                                                     0000-0001-9521-413X
#  13118  Marked line was below 130 and impeded by a bra...  0009-0009-2144-0906
#  13119                                                     0000-0001-9521-413X
#  13120               Verified height with 2shot VD method  0000-0001-9521-413X
#  13121  Could not locate individual. Tag found unattac...  0009-0009-2144-0906
#
#                  measuredBy                     dataEntryRecordID      dataQF  \
#  0        krian@neoninc.org                                        legacyData
#  1        krian@neoninc.org                                        legacyData
#  2        krian@neoninc.org                                        legacyData
#  3        krian@neoninc.org                                        legacyData
#  4        krian@neoninc.org                                        legacyData
#  ...                    ...                                   ...         ...
#  13117  0009-0002-2294-9551  418da61f-f26c-491c-a47f-83bb9716cda4
#  13118  0009-0001-3938-7148  3162149b-1c5d-438b-a678-f3a2a7cad2c1
#  13119  0009-0002-2294-9551  9fa50c39-899a-4f27-b956-1d59d7c7e4a6
#  13120  0009-0002-2294-9551  4cae3a36-2729-4953-b426-42d3988aa385
#  13121  0009-0001-3938-7148  2321fc95-a4bc-47e0-ac45-ad61d8101681
#
#          publicationDate       release
#  0      20250122T230548Z  RELEASE-2025
#  1      20250122T230548Z  RELEASE-2025
#  2      20250122T230548Z  RELEASE-2025
#  3      20250122T230548Z  RELEASE-2025
#  4      20250122T230548Z  RELEASE-2025
#  ...                 ...           ...
#  13117  20250122T230603Z  RELEASE-2025
#  13118  20250122T230603Z  RELEASE-2025
#  13119  20250122T230603Z  RELEASE-2025
#  13120  20250122T230603Z  RELEASE-2025
#  13121  20250122T230603Z  RELEASE-2025
#
#  [13122 rows x 43 columns],
#  'vst_mappingandtagging':                                        uid          namedLocation        date  \
#  0     2b0944f9-99c6-4cdf-920d-fe2696b5a07f  ABBY_063.basePlot.vst  2015-07-23
#  1     a67afcd3-69aa-4e1b-bc4d-aa998ad12058  ABBY_063.basePlot.vst  2015-07-23
#  2     56c4b5d8-85a2-4a5d-aaf2-de492030f1b7  ABBY_063.basePlot.vst  2015-07-23
#  3     d277c3cc-49f4-4c28-b47a-de24109aa493  ABBY_063.basePlot.vst  2015-07-23
#  4     cf715a4b-b588-47c2-add8-72a7f0a3a0d9  ABBY_063.basePlot.vst  2015-07-23
#  ...                                    ...                    ...         ...
#  4324  e917b357-0a4c-4ada-9ecd-54492636803c  ABBY_017.basePlot.vst  2024-12-03
#  4325  0df7a57a-30fd-4810-b52a-9442dea6b0fc  ABBY_017.basePlot.vst  2024-12-03
#  4326  790176b6-50dc-461e-a7a7-26e5d4287cf0  ABBY_017.basePlot.vst  2024-12-03
#  4327  cc907199-4191-4257-9bd9-7cf0a15b4700  ABBY_017.basePlot.vst  2024-12-03
#  4328  8cb321a5-47ea-4b79-9d4c-fb9db2dd514c  ABBY_017.basePlot.vst  2024-12-03
#
#              eventID domainID siteID    plotID pointID  stemDistance  \
#  0     vst_ABBY_2015      D16   ABBY  ABBY_063      57           7.4
#  1     vst_ABBY_2015      D16   ABBY  ABBY_063      39          16.9
#  2     vst_ABBY_2015      D16   ABBY  ABBY_063                   NaN
#  3     vst_ABBY_2015      D16   ABBY  ABBY_063                   NaN
#  4     vst_ABBY_2015      D16   ABBY  ABBY_063      57           9.7
#  ...             ...      ...    ...       ...     ...           ...
#  4324  vst_ABBY_2024      D16   ABBY  ABBY_017                   NaN
#  4325  vst_ABBY_2024      D16   ABBY  ABBY_017                   NaN
#  4326  vst_ABBY_2024      D16   ABBY  ABBY_017                   NaN
#  4327  vst_ABBY_2024      D16   ABBY  ABBY_017                   NaN
#  4328  vst_ABBY_2024      D16   ABBY  ABBY_017                   NaN
#
#        stemAzimuth  ... identificationReferences morphospeciesID  \
#  0            94.8  ...
#  1            75.2  ...
#  2             NaN  ...
#  3             NaN  ...
#  4           111.9  ...
#  ...           ...  ...                      ...             ...
#  4324          NaN  ...
#  4325          NaN  ...
#  4326          NaN  ...
#  4327          NaN  ...
#  4328          NaN  ...
#
#       morphospeciesIDRemarks identificationQualifier  \
#  0
#  1
#  2
#  3
#  4
#  ...                     ...                     ...
#  4324
#  4325
#  4326
#  4327
#  4328
#
#                                      remarks           measuredBy  \
#  0                                              krian@neoninc.org
#  1                                              krian@neoninc.org
#  2     On subplot line; retained in dataset.    krian@neoninc.org
#  3             no transcription errors found    krian@neoninc.org
#  4                                              krian@neoninc.org
#  ...                                     ...                  ...
#  4324                                         0009-0005-4412-7737
#  4325                                         0000-0003-2086-5426
#  4326                                         0009-0005-4412-7737
#  4327                                         0000-0003-2086-5426
#  4328                                         0000-0003-2086-5426
#
#                 recordedBy dataQF   publicationDate       release
#  0     kzias@field-ops.org         20250122T230135Z  RELEASE-2025
#  1     kzias@field-ops.org         20250122T230135Z  RELEASE-2025
#  2     kzias@field-ops.org         20250122T230135Z  RELEASE-2025
#  3     kzias@field-ops.org         20250122T230135Z  RELEASE-2025
#  4     kzias@field-ops.org         20250122T230135Z  RELEASE-2025
#  ...                   ...    ...               ...           ...
#  4324  0000-0003-2086-5426         20250122T230135Z  RELEASE-2025
#  4325  0009-0005-4412-7737         20250122T230135Z  RELEASE-2025
#  4326  0000-0003-2086-5426         20250122T230135Z  RELEASE-2025
#  4327  0009-0005-4412-7737         20250122T230135Z  RELEASE-2025
#  4328  0009-0005-4412-7737         20250122T230135Z  RELEASE-2025
#
#  [4329 rows x 33 columns],
#  'vst_non-woody':                                        uid          namedLocation        date  \
#  0     7b73bc3f-8efc-4cc2-9bd5-a16ecf0d133b  ABBY_063.basePlot.vst  2015-07-23
#  1     821c4d56-7c2a-4134-9779-f2145a17ee0c  ABBY_063.basePlot.vst  2015-07-23
#  2     7ad8f526-ac48-4ef3-bc02-8085eee67afa  ABBY_063.basePlot.vst  2015-07-23
#  3     ee2604a3-7aac-486a-9a73-cf49aaff46f3  ABBY_063.basePlot.vst  2015-07-23
#  4     e24d3920-7c5b-4de0-8171-1c6c3b5db91a  ABBY_068.basePlot.vst  2015-07-25
#  ...                                    ...                    ...         ...
#  6143  78c9b08c-5594-4934-a243-6d7ac18c0fb0  ABBY_064.basePlot.vst  2021-08-19
#  6144  7e72c7d1-31a8-4b1b-94d1-110684d4dc47  ABBY_062.basePlot.vst  2021-08-19
#  6145  6047bf57-dc3f-41a6-9ae0-d1831991d8b0  ABBY_064.basePlot.vst  2021-08-19
#  6146  10517b8e-6d28-44cc-a3cf-a3f7e6a97c75  ABBY_062.basePlot.vst  2021-08-19
#  6147  5bb9a4b8-8643-4adb-971b-83ecf609ec5d  ABBY_062.basePlot.vst  2021-08-19
#
#              eventID domainID siteID    plotID     subplotID tagID  \
#  0     vst_ABBY_2015      D16   ABBY  ABBY_063  21_unknown_1
#  1     vst_ABBY_2015      D16   ABBY  ABBY_063  39_unknown_1
#  2     vst_ABBY_2015      D16   ABBY  ABBY_063  31_unknown_4
#  3     vst_ABBY_2015      D16   ABBY  ABBY_063  48_unknown_3
#  4     vst_ABBY_2015      D16   ABBY  ABBY_068  39_unknown_1
#  ...             ...      ...    ...       ...           ...   ...
#  6143  vst_ABBY_2021      D16   ABBY  ABBY_064        21_3_1
#  6144  vst_ABBY_2021      D16   ABBY  ABBY_062        39_3_1
#  6145  vst_ABBY_2021      D16   ABBY  ABBY_064        21_3_1
#  6146  vst_ABBY_2021      D16   ABBY  ABBY_062        48_3_3
#  6147  vst_ABBY_2021      D16   ABBY  ABBY_062        39_3_1
#
#                       individualID  ... newPadCount stemCount branchCount  \
#  0     TEMP.PLA.NW.ABBY.2015.63152  ...         NaN       NaN         NaN
#  1     TEMP.PLA.NW.ABBY.2015.63153  ...         NaN       NaN         NaN
#  2     TEMP.PLA.NW.ABBY.2015.63151  ...         NaN       NaN         NaN
#  3     TEMP.PLA.NW.ABBY.2015.63154  ...         NaN       NaN         NaN
#  4     TEMP.PLA.NW.ABBY.2015.68153  ...         NaN       NaN         NaN
#  ...                           ...  ...         ...       ...         ...
#  6143   TEMP.PLA.NW.ABBY.2021.6444  ...         NaN       NaN         NaN
#  6144   TEMP.PLA.NW.ABBY.2021.6224  ...         NaN       NaN         NaN
#  6145   TEMP.PLA.NW.ABBY.2021.6440  ...         NaN       NaN         NaN
#  6146   TEMP.PLA.NW.ABBY.2021.6254  ...         NaN       NaN         NaN
#  6147   TEMP.PLA.NW.ABBY.2021.6219  ...         NaN       NaN         NaN
#
#       meanBranchLength    remarks           measuredBy  \
#  0                 NaN    17 PTAQ    krian@neoninc.org
#  1                 NaN    13 PTAQ    krian@neoninc.org
#  2                 NaN    10 PTAQ    krian@neoninc.org
#  3                 NaN    13 PTAQ    krian@neoninc.org
#  4                 NaN     8 PTAQ    krian@neoninc.org
#  ...               ...        ...                  ...
#  6143              NaN             0000-0003-2593-761X
#  6144              NaN             0000-0002-4816-2610
#  6145              NaN             0000-0003-2593-761X
#  6146              NaN             0000-0002-4816-2610
#  6147              NaN  Bent stem  0000-0002-4816-2610
#
#                     recordedBy                     dataEntryRecordID  \
#  0         kzias@field-ops.org
#  1         kzias@field-ops.org
#  2         kzias@field-ops.org
#  3         kzias@field-ops.org
#  4     emccarthy@field-ops.org
#  ...                       ...                                   ...
#  6143      0000-0002-4816-2610  956fdafe-7287-4c89-91d0-ec259f3cd645
#  6144      0000-0003-2593-761X  333b10d4-bc1e-4379-91a5-5cc7ce3e5610
#  6145      0000-0002-4816-2610  db6f1cdc-08f0-4a12-9d5e-ceca266f57ce
#  6146      0000-0003-2593-761X  6cada225-b57c-4571-b0ae-fe0b923a4d6d
#  6147      0000-0003-2593-761X  f7b79c72-50b4-4883-9b8d-eef4ef89549c
#
#         publicationDate       release
#  0     20250122T230548Z  RELEASE-2025
#  1     20250122T230548Z  RELEASE-2025
#  2     20250122T230548Z  RELEASE-2025
#  3     20250122T230548Z  RELEASE-2025
#  4     20250122T230548Z  RELEASE-2025
#  ...                ...           ...
#  6143  20250122T230421Z  RELEASE-2025
#  6144  20250122T230421Z  RELEASE-2025
#  6145  20250122T230421Z  RELEASE-2025
#  6146  20250122T230421Z  RELEASE-2025
#  6147  20250122T230421Z  RELEASE-2025
#
#  [6148 rows x 48 columns],
#  'vst_perplotperyear':                                       uid          namedLocation        date  \
#  0    781f7045-9fc8-43ed-89db-e8d98730ba96  ABBY_063.basePlot.vst  2015-07-23
#  1    99516959-46e4-47c3-b124-cbc2eae1b089  ABBY_068.basePlot.vst  2015-07-25
#  2    c91a5422-1c43-4ca0-9530-cd4fc085d5bf  ABBY_065.basePlot.vst  2015-07-27
#  3    2fd8bbaf-e5cf-40ee-bd13-1f28a6873519  ABBY_067.basePlot.vst  2015-07-27
#  4    3617b468-8125-4c4d-8d8f-06a5c5c97351  ABBY_066.basePlot.vst  2015-07-28
#  ..                                    ...                    ...         ...
#  125  7a9f3d0a-f79e-4188-8189-bf8968230016  ABBY_061.basePlot.vst  2023-08-28
#  126  cff5bca0-34ff-4204-8a14-9f1d49a149b4  ABBY_062.basePlot.vst  2023-09-04
#  127  e23dc25e-3ddc-4e0e-949f-e067d3624d4a  ABBY_063.basePlot.vst  2023-09-05
#  128  71461447-8c89-4641-bbea-cda65aa18e49  ABBY_070.basePlot.vst  2023-10-05
#  129  82737eb1-2140-4088-a2ac-07d9d50af572  ABBY_073.basePlot.vst  2023-10-30
#
#      nonwoodyCollectDate domainID siteID    plotID plotType  \
#  0                  None      D16   ABBY  ABBY_063    tower
#  1                  None      D16   ABBY  ABBY_068    tower
#  2                  None      D16   ABBY  ABBY_065    tower
#  3                  None      D16   ABBY  ABBY_067    tower
#  4                  None      D16   ABBY  ABBY_066    tower
#  ..                  ...      ...    ...       ...      ...
#  125                None      D16   ABBY  ABBY_061    tower
#  126                None      D16   ABBY  ABBY_062    tower
#  127                None      D16   ABBY  ABBY_063    tower
#  128                None      D16   ABBY  ABBY_070    tower
#  129                None      D16   ABBY  ABBY_073    tower
#
#                 nlcdClass  decimalLatitude  ...  totalSampledAreaShrubSapling  \
#  0        evergreenForest        45.760513  ...                         800.0
#  1        evergreenForest        45.760510  ...                         100.0
#  2    grasslandHerbaceous        45.762196  ...                         100.0
#  3        evergreenForest        45.760563  ...                         100.0
#  4        evergreenForest        45.763502  ...                         400.0
#  ..                   ...              ...  ...                           ...
#  125      evergreenForest        45.762451  ...                         400.0
#  126      evergreenForest        45.763476  ...                         100.0
#  127      evergreenForest        45.760513  ...                         400.0
#  128      evergreenForest        45.761334  ...                         400.0
#  129      evergreenForest        45.762944  ...                          40.0
#
#      totalSampledAreaLiana  totalSampledAreaFerns  totalSampledAreaOther  \
#  0                   800.0                    NaN                  800.0
#  1                   800.0                    NaN                    4.0
#  2                   800.0                    NaN                   40.0
#  3                   800.0                    NaN                    4.0
#  4                   800.0                    NaN                  400.0
#  ..                    ...                    ...                    ...
#  125                 800.0                    NaN                   12.0
#  126                 800.0                    NaN                  800.0
#  127                 800.0                    NaN                    NaN
#  128                 800.0                    NaN                  800.0
#  129                 800.0                    NaN                  800.0
#
#                                                 remarks            measuredBy  \
#  0                      ferns only counted not measured     krian@neoninc.org
#  1    Fern nested subplot size of 1 square meter; fe...  shiebert@neoninc.org
#  2    Fern nested subplot size of 10 square meters; ...  shiebert@neoninc.org
#  3    Fern nested subplot size of 1 square meter; fe...   lwade@field-ops.org
#  4    Fern nested subplot size of 100 square meters;...     krian@neoninc.org
#  ..                                                 ...                   ...
#  125
#  126
#  127
#  128
#  129
#
#              recordedBy      dataQF   publicationDate       release
#  0    krian@neoninc.org  legacyData  20250122T230548Z  RELEASE-2025
#  1    krian@neoninc.org  legacyData  20250122T230548Z  RELEASE-2025
#  2    krian@neoninc.org  legacyData  20250122T230548Z  RELEASE-2025
#  3    krian@neoninc.org  legacyData  20250122T230548Z  RELEASE-2025
#  4    krian@neoninc.org  legacyData  20250122T230548Z  RELEASE-2025
#  ..                 ...         ...               ...           ...
#  125                                 20250122T231936Z  RELEASE-2025
#  126                                 20250122T230222Z  RELEASE-2025
#  127                                 20250122T230222Z  RELEASE-2025
#  128                                 20250122T230407Z  RELEASE-2025
#  129                                 20250122T230407Z  RELEASE-2025
#
#  [130 rows x 52 columns],
#  'vst_shrubgroup':                                       uid          namedLocation        date  \
#  0    5efa4233-a0b4-4612-bdc1-52d13443b5d2  ABBY_063.basePlot.vst  2015-07-23
#  1    cb8eaa43-0160-4cfc-96f9-92232c7a2379  ABBY_063.basePlot.vst  2015-07-23
#  2    2eca638c-8695-40f8-bdd7-3f36f356f767  ABBY_063.basePlot.vst  2015-07-23
#  3    7c2bed83-29f1-4eb0-bc29-08ee9c84a7c6  ABBY_063.basePlot.vst  2015-07-23
#  4    ab56af63-5a17-4781-a31d-026e95d360ed  ABBY_063.basePlot.vst  2015-07-23
#  ..                                    ...                    ...         ...
#  179  55c358cb-1ee3-4382-911e-dd65787a33e5  ABBY_005.basePlot.vst  2019-10-28
#  180  43da4b2f-1ad5-42a0-8562-b14ea2487527  ABBY_005.basePlot.vst  2019-10-28
#  181  1595dba1-a553-4358-ac51-929695126415  ABBY_005.basePlot.vst  2019-10-29
#  182  338a6fff-0458-40a2-8813-19631c1c7e57  ABBY_005.basePlot.vst  2019-10-29
#  183  6f87ef1d-4431-4225-a21f-446828572d9b  ABBY_005.basePlot.vst  2019-10-29
#
#             eventID domainID siteID    plotID      subplotID groupID taxonID  \
#  0    vst_ABBY_2015      D16   ABBY  ABBY_063         21_400   21_NA    ACCI
#  1    vst_ABBY_2015      D16   ABBY  ABBY_063         39_400   39_NA    ACCI
#  2    vst_ABBY_2015      D16   ABBY  ABBY_063         21_400   21_NA    ACCI
#  3    vst_ABBY_2015      D16   ABBY  ABBY_063         21_400   21_NA    ACCI
#  4    vst_ABBY_2015      D16   ABBY  ABBY_063         39_400   39_NA   SPDOD
#  ..             ...      ...    ...       ...            ...     ...     ...
#  179  vst_ABBY_2019      D16   ABBY  ABBY_005  41_10_unknown   41_01    RUUR
#  180  vst_ABBY_2019      D16   ABBY  ABBY_005  41_10_unknown   41_01   RUAR9
#  181  vst_ABBY_2019      D16   ABBY  ABBY_005  32_10_unknown   32_01   RUAR9
#  182  vst_ABBY_2019      D16   ABBY  ABBY_005  32_10_unknown   32_01    RUUR
#  183  vst_ABBY_2019      D16   ABBY  ABBY_005  32_10_unknown   32_01    RUSP
#
#       ... livePercent deadPercent canopyArea meanHeight  remarks  \
#  0    ...       100.0         0.0        1.0       0.88
#  1    ...        95.0         5.0        1.0       2.74
#  2    ...       100.0         0.0        1.0       0.56
#  3    ...        90.0        10.0        1.0       0.96
#  4    ...        95.0         5.0        1.0       0.92
#  ..   ...         ...         ...        ...        ...      ...
#  179  ...        99.0         1.0       60.0       2.34
#  180  ...        96.0         4.0       60.0       2.34
#  181  ...        70.0        30.0        6.5       1.32
#  182  ...        95.0         5.0        6.5       1.32
#  183  ...         0.0       100.0        6.5       1.32
#
#                 measuredBy           recordedBy      dataQF   publicationDate  \
#  0    shiebert@neoninc.org  kzias@field-ops.org  legacyData  20250122T230548Z
#  1    shiebert@neoninc.org  kzias@field-ops.org  legacyData  20250122T230548Z
#  2    shiebert@neoninc.org  kzias@field-ops.org  legacyData  20250122T230548Z
#  3    shiebert@neoninc.org  kzias@field-ops.org  legacyData  20250122T230548Z
#  4    shiebert@neoninc.org  kzias@field-ops.org  legacyData  20250122T230548Z
#  ..                    ...                  ...         ...               ...
#  179   0000-0001-9932-2330  0000-0001-8397-9370              20250122T230136Z
#  180   0000-0001-9932-2330  0000-0001-8397-9370              20250122T230136Z
#  181   0000-0003-1908-4817  0000-0001-9932-2330              20250122T230136Z
#  182   0000-0003-1908-4817  0000-0001-9932-2330              20250122T230136Z
#  183   0000-0003-1908-4817  0000-0001-9932-2330              20250122T230136Z
#
#            release
#  0    RELEASE-2025
#  1    RELEASE-2025
#  2    RELEASE-2025
#  3    RELEASE-2025
#  4    RELEASE-2025
#  ..            ...
#  179  RELEASE-2025
#  180  RELEASE-2025
#  181  RELEASE-2025
#  182  RELEASE-2025
#  183  RELEASE-2025
#
#  [184 rows x 25 columns],
#  'plot_biomass':     siteID    plotID  year  plotArea_m2  tree_AGBJenkins  tree_AGBChojnacky  \
#  0     ABBY  ABBY_001  2016       1600.0       115.219626         110.427987
#  1     ABBY  ABBY_001  2019       1600.0       118.515381         112.831040
#  2     ABBY  ABBY_002  2016       1600.0         0.000000           0.000000
#  3     ABBY  ABBY_002  2019       1600.0         0.000000           0.000000
#  4     ABBY  ABBY_003  2016       1600.0         5.049853           4.470525
#  ..     ...       ...   ...          ...              ...                ...
#  125   ABBY  ABBY_076  2016       1600.0         5.445421           4.796577
#  126   ABBY  ABBY_076  2017       1600.0         5.731298           5.048668
#  127   ABBY  ABBY_076  2018       1600.0         6.217968           5.482550
#  128   ABBY  ABBY_076  2019       1600.0         6.739843           5.952529
#  129   ABBY  ABBY_076  2021       1600.0        12.099646          10.693410
#
#       tree_AGBAnnighofer  n_trees  small_woody_AGBJenkins  \
#  0                   NaN       11                0.489534
#  1                   NaN        9                0.672824
#  2                   0.0        0                0.279506
#  3                   0.0        0                1.698501
#  4                   NaN       13                2.026043
#  ..                  ...      ...                     ...
#  125                 NaN       20                4.210501
#  126                 NaN       20                6.260232
#  127                 NaN       21                9.019252
#  128                 NaN       21               12.337376
#  129                 NaN       36                4.138767
#
#       small_woody_AGBChojnacky  small_woody_AGBAnnighofer  n_small_woody_total  \
#  0                    0.438844                   0.420809                   41
#  1                    0.604206                   0.393183                   41
#  2                    0.200257                   0.656258                   56
#  3                    1.411427                   0.691158                   60
#  4                    1.914622                   0.600059                  111
#  ..                        ...                        ...                  ...
#  125                  4.324942                   1.145127                  257
#  126                  6.582992                   0.880298                  248
#  127                  9.824772                   0.719082                  232
#  128                 13.664755                   0.694286                  224
#  129                  4.378518                   0.675689                  218
#
#       n_small_woody_measured  n_unaccounted_trees  total_AGBJenkins  \
#  0                        18                    2        115.709160
#  1                        19                    2        119.188205
#  2                        50                   21          0.279506
#  3                        51                   21          1.698501
#  4                        53                    5          7.075896
#  ..                      ...                  ...               ...
#  125                      70                    0          9.655921
#  126                      73                    0         11.991531
#  127                      68                    0         15.237220
#  128                      68                    0         19.077219
#  129                      53                    0         16.238413
#
#       total_AGBChojnacky  total_AGBAnnighofer    growth  growth_cumu
#  0            110.866831             0.420809       NaN     1.159682
#  1            113.435247             0.393183  1.159682     1.159682
#  2              0.200257             0.656258       NaN     0.472998
#  3              1.411427             0.691158  0.472998     0.472998
#  4              6.385147             0.600059       NaN     2.465262
#  ..                  ...                  ...       ...          ...
#  125            9.121519             1.145127       NaN     1.489799
#  126           11.631660             0.880298  2.335609     1.489799
#  127           15.307322             0.719082  3.245689     1.489799
#  128           19.617284             0.694286  3.839999     1.489799
#  129           15.071928             0.675689 -1.419403     1.489799
#
#  [130 rows x 19 columns],
#  'unaccounted_trees':     siteID    plotID             individualID  \
#  0     ABBY  ABBY_017  NEON.PLA.D16.ABBY.07786
#  1     ABBY  ABBY_065  NEON.PLA.D16.ABBY.03107
#  2     ABBY  ABBY_009  NEON.PLA.D16.ABBY.07471
#  3     ABBY  ABBY_002  NEON.PLA.D16.ABBY.08437
#  4     ABBY  ABBY_002  NEON.PLA.D16.ABBY.08177
#  ..     ...       ...                      ...
#  406   ABBY  ABBY_065  NEON.PLA.D16.ABBY.03114
#  407   ABBY  ABBY_065  NEON.PLA.D16.ABBY.03110
#  408   ABBY  ABBY_011  NEON.PLA.D16.ABBY.08427
#  409   ABBY  ABBY_007  NEON.PLA.D16.ABBY.08187
#  410   ABBY  ABBY_062  NEON.PLA.D16.ABBY.08091
#
#                                          scientificName taxonID        status  \
#  0    Pseudotsuga menziesii (Mirb.) Franco var. menz...   PSMEM    UNMEASURED
#  1                             Gaultheria shallon Pursh    GASH    UNMEASURED
#  2       Prunus emarginata (Douglas ex Hook.) D. Dietr.    PREM    UNMEASURED
#  3       Prunus emarginata (Douglas ex Hook.) D. Dietr.    PREM    UNMEASURED
#  4       Prunus emarginata (Douglas ex Hook.) D. Dietr.    PREM    UNMEASURED
#  ..                                                 ...     ...           ...
#  406                              Acer circinatum Pursh    ACCI    UNMEASURED
#  407                           Gaultheria shallon Pursh    GASH    UNMEASURED
#  408                 Holodiscus discolor (Pursh) Maxim.    HODI    UNMEASURED
#  409                          Vaccinium parvifolium Sm.    VAPA    UNMEASURED
#  410  Pseudotsuga menziesii (Mirb.) Franco var. menz...   PSMEM  NO_ALLOMETRY
#
#                                                  reason
#  0                   Never measured in survey campaigns
#  1                   Never measured in survey campaigns
#  2                   Never measured in survey campaigns
#  3                   Never measured in survey campaigns
#  4                   Never measured in survey campaigns
#  ..                                                 ...
#  406                 Never measured in survey campaigns
#  407                 Never measured in survey campaigns
#  408                 Never measured in survey campaigns
#  409                 Never measured in survey campaigns
#  410  Has diameter measurements but no biomass estim...
#
#  [411 rows x 7 columns],
#  'individual_trees':      siteID    plotID             individualID  year  AGBJenkins  \
#  0      ABBY  ABBY_075  NEON.PLA.D16.ABBY.00001  2021   21.958470
#  1      ABBY  ABBY_075  NEON.PLA.D16.ABBY.00005  2021   56.659165
#  2      ABBY  ABBY_075  NEON.PLA.D16.ABBY.00012  2016    0.000000
#  3      ABBY  ABBY_075  NEON.PLA.D16.ABBY.00012  2017    0.000000
#  4      ABBY  ABBY_075  NEON.PLA.D16.ABBY.00012  2018    0.000000
#  ...     ...       ...                      ...   ...         ...
#  4253   ABBY  ABBY_023  NEON.PLA.D16.ABBY.09945  2019   29.413027
#  4254   ABBY  ABBY_023  NEON.PLA.D16.ABBY.09946  2016   16.531197
#  4255   ABBY  ABBY_023  NEON.PLA.D16.ABBY.09946  2019   16.531197
#  4256   ABBY  ABBY_023  NEON.PLA.D16.ABBY.09947  2016   14.109269
#  4257   ABBY  ABBY_023  NEON.PLA.D16.ABBY.09947  2019   14.109269
#
#        AGBChojnacky  AGBAnnighofer  growth_AGBJenkins  growth_cumu_AGBJenkins  \
#  0        19.068443            NaN                NaN                     NaN
#  1        50.004457            NaN                NaN                     NaN
#  2         0.000000            0.0                NaN                     0.0
#  3         0.000000            0.0                0.0                     0.0
#  4         0.000000            0.0                0.0                     0.0
#  ...            ...            ...                ...                     ...
#  4253           NaN            NaN                0.0                     0.0
#  4254     15.376333            NaN                NaN                     0.0
#  4255     15.376333            NaN                0.0                     0.0
#  4256     12.995139            NaN                NaN                     0.0
#  4257     12.995139            NaN                0.0                     0.0
#
#        growth_AGBChojnacky  ...  corrected_is_dead  gapFilling  \
#  0                     NaN  ...              False    ORIGINAL
#  1                     NaN  ...              False    ORIGINAL
#  2                     NaN  ...               True    ORIGINAL
#  3                     0.0  ...               True    ORIGINAL
#  4                     0.0  ...               True    ORIGINAL
#  ...                   ...  ...                ...         ...
#  4253                  NaN  ...              False    ORIGINAL
#  4254                  NaN  ...              False      FILLED
#  4255                  0.0  ...              False    ORIGINAL
#  4256                  NaN  ...              False      FILLED
#  4257                  0.0  ...              False    ORIGINAL
#
#                                           scientificName  taxonID        genus  \
#  0     Pseudotsuga menziesii (Mirb.) Franco var. menz...    PSMEM  Pseudotsuga
#  1     Pseudotsuga menziesii (Mirb.) Franco var. menz...    PSMEM  Pseudotsuga
#  2     Pseudotsuga menziesii (Mirb.) Franco var. menz...    PSMEM  Pseudotsuga
#  3     Pseudotsuga menziesii (Mirb.) Franco var. menz...    PSMEM  Pseudotsuga
#  4     Pseudotsuga menziesii (Mirb.) Franco var. menz...    PSMEM  Pseudotsuga
#  ...                                                 ...      ...          ...
#  4253     Prunus emarginata (Douglas ex Hook.) D. Dietr.     PREM       Prunus
#  4254     Prunus emarginata (Douglas ex Hook.) D. Dietr.     PREM       Prunus
#  4255     Prunus emarginata (Douglas ex Hook.) D. Dietr.     PREM       Prunus
#  4256     Prunus emarginata (Douglas ex Hook.) D. Dietr.     PREM       Prunus
#  4257     Prunus emarginata (Douglas ex Hook.) D. Dietr.     PREM       Prunus
#
#          family taxonRank pointID stemDistance stemAzimuth
#  0     Pinaceae   variety      21          4.6        77.1
#  1     Pinaceae   variety      21          2.9        31.1
#  2     Pinaceae   variety      41          7.4       348.5
#  3     Pinaceae   variety      41          7.4       348.5
#  4     Pinaceae   variety      41          7.4       348.5
#  ...        ...       ...     ...          ...         ...
#  4253  Rosaceae   species      51          4.6       230.4
#  4254  Rosaceae   species      51         10.1       209.6
#  4255  Rosaceae   species      51         10.1       209.6
#  4256  Rosaceae   species      51          9.0       213.2
#  4257  Rosaceae   species      51          9.0       213.2
#
#  [4258 rows x 26 columns],
#  'site_id': 'ABBY',
#  'metadata': {'apply_gap_filling': True,
#   'apply_dead_corrections': True,
#   'site_has_agb_data': True,
#   'n_plots': 34,
#   'n_plot_years': 130,
#   'n_unaccounted_trees': 411,
#   'n_individual_tree_records': 4258}}
